# %%
! pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/AI/Indian_Railway'
# Out:
# /content/drive/MyDrive/AI/Indian_Railway

# %%
import os

# Paths to check
train_dir = "/content/drive/MyDrive/AI/Indian_Railway/Data/train/images"
val_dir = "/content/drive/MyDrive/AI/Indian_Railway/Data/val/images"

# Check existence
print("Train Directory Exists:", os.path.exists(train_dir))
print("Validation Directory Exists:", os.path.exists(val_dir))

# Check number of images
if os.path.exists(train_dir):
    print("Number of Training Images:", len(os.listdir(train_dir)))
if os.path.exists(val_dir):
    print("Number of Validation Images:", len(os.listdir(val_dir)))
# Out:
# Train Directory Exists: True
# Validation Directory Exists: True
# Number of Training Images: 81
# Number of Validation Images: 20

# %%
# Path to data.yaml
data_yaml_path = "/content/drive/MyDrive/AI/Indian_Railway/Data/data.yaml"

# Check content
with open(data_yaml_path, "r") as file:
    print(file.read())
# Out:
# path: /content/drive/MyDrive/AI/Indian_Railway/Data
# train: /content/drive/MyDrive/AI/Indian_Railway/Data/train/images
# val: /content/drive/MyDrive/AI/Indian_Railway/Data/val/images
#
# # Classes
# nc : 6
# names: ['OHE Pole', 'Signal Pole', 'Silver Box', 'Sign Board', 'Tunnel', 'Station Name Board']

# %%
# !yolo train data=/content/drive/MyDrive/AI/Indian_Railway/Data/data.yaml model=yolo11n.pt epochs=50 batch=8 imgsz=640
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
! yolo task=detect mode=predict model='/content/drive/MyDrive/AI/Indian_Railway/runs/detect/train6/weights/best.pt' imgsz=640 data=data.yaml source='/content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4' show_labels=True show=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 2 OHE Poles, 45.1ms
# video 1/1 (frame 2/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 1 OHE Pole, 11.3ms
# video 1/1 (frame 3/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 2 OHE Poles, 11.3ms
# video 1/1 (frame 4/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 2 OHE Poles, 12.5ms
# video 1/1 (frame 5/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 3 OHE Poles, 12.0ms
# video 1/1 (frame 6/362) /content/drive/MyDrive/AI/Indian_Railway/Data/Railway_2.mp4: 384x640 3 OHE Poles, 12.4ms
# ...
